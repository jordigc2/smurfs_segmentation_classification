# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from jsonParser import JSONParserCOCO
import ipywidgets as widgets
from IPython.display import display

# %%
data_path = "/data/smurfs_coco_format/"
json_file_name = "updated_result.json"

dataset = JSONParserCOCO(data_path, json_file_name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[36], line 4
#       1 data_path = "/data/smurfs_coco_format/"
#       2 json_file_name = "updated_result.json"
# ----> 4 dataset = JSONParserCOCO(data_path, json_file_name)
#
# File /workspace/jsonParser.py:11, in JSONParserCOCO.__init__(self, data_path, json_file_name)
#       9 def __init__(self, data_path, json_file_name) -> None:
# ---> 11     with open(data_path + json_file_name, "r") as json_file:
#      12         self.smurfs_data = json.load(json_file)
#      14     self.data_path = data_path
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data/smurfs_coco_format/updated_result.json'

# %%
def update_annot_cat(dataset):
    print("Category Ids:", dataset.categ_dict)
    
    while True:
        ann_id = input("Enter Annotation Id: ")
    
        if not ann_id.isdigit():
            break
            
        cat_id = input("Enter Category Id: ")
    
        if not cat_id.isdigit():
            break
        
        dataset.set_annot_cat_by_id(int(cat_id), int(ann_id))
        dataset.update_json_cat_by_ann_id(int(cat_id), int(ann_id))
        print(f'Annotation ID {ann_id} with new category id {cat_id}')
    
        print("-------------")

# %%
dataset.visualize_annot_by_imgid(1)

# %%
update_annot_cat(dataset)
# Out:
# Category Ids: {0: {'id': 0, 'name': 'Smurf'}, 1: {'id': 1, 'name': 'Papa Smurf'}, 2: {'id': 2, 'name': 'Smurfette'}, 3: {'id': 3, 'name': 'Vanity Smurf'}}
# Enter Annotation Id:  22
# Enter Category Id:  2
# Annotation ID 22 with new category id 2
# -------------
# Enter Annotation Id:  23
# Enter Category Id:  1
# Annotation ID 23 with new category id 1
# -------------
# Enter Annotation Id:

# %%
dataset.ann_dict[22]
# Out:
# {'id': 22,
#  'image_id': 1,
#  'category_id': 2,
#  'segmentation': [[247.46666666666667,
#    537.6324951644101,
#    211.20000000000002,
#    558.9671179883945,
#    217.60000000000005,
#    610.1702127659574,
#    200.53333333333333,
#    633.6382978723406,
#    192.0,
#    603.7698259187621,
#    174.93333333333334,
#    614.4371373307544,
#    160.0,
#    593.1025145067698,
#    151.46666666666667,
#    618.7040618955513,
#    168.53333333333333,
#    659.239845261122,
#    200.53333333333333,
#    682.7079303675049,
#    196.26666666666668,
#    701.9090909090909,
#    177.06666666666666,
#    716.8433268858801,
#    172.80000000000004,
#    776.5802707930367,
#    145.06666666666666,
#    808.5822050290136,
#    162.13333333333333,
#    823.5164410058027,
#    211.20000000000002,
#    804.3152804642166,
#    211.20000000000002,
#    740.311411992263,
#    228.26666666666665,
#    755.2456479690521,
#    247.46666666666667,
#    806.448742746615,
#    236.80000000000004,
#    834.183752417795,
#    249.6,
#    846.9845261121857,
#    294.3999999999999,
#    834.183752417795,
#    294.3999999999999,
#    817.1160541586073,
#    256.0,
#    755.2456479690521,
#    281.5999999999999,
#    763.7794970986461,
#    305.06666666666666,
#    742.4448742746615,
#    337.06666666666666,
#    723.2437137330755,
#    360.53333333333336,
#    710.4429400386849,
#    362.962051282051,
#    691.0120220205328,
#    364.8,
#    676.3075435203095,
#    317.8666666666667,
#    650.7059961315277,
#    354.1333333333333,
#    603.7698259187621,
#    341.3333333333334,
#    556.8336557059962,
#    309.3333333333333,
#    514.1644100580271,
#    262.40000000000003,
#    514.1644100580271]],
#  'bbox': [145.06666666666666,
#   514.1644100580271,
#   219.73333333333335,
#   332.8201160541586],
#  'ignore': 0,
#  'iscrowd': 0,
#  'area': 40518.71566731203}
